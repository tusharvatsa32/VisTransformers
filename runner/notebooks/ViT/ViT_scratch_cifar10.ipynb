# %% [markdown]
# <a href="https://colab.research.google.com/github/tusharvatsa32/VisTransformers/blob/main/Code/ViT_scratch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Import Libraries

# %%
# !nvidia-smi
# Out:
# Thu Apr 29 20:08:00 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.19.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   41C    P0    27W / 300W |      0MiB / 16160MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !pip install -q einops

# %%
import os
import random
import numpy as np
import torch
import torch.nn as nn
import torchvision
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, models, transforms
from torch import einsum
from PIL import Image
from torch.utils.data import DataLoader, Dataset
from torchvision import datasets, transforms
from tqdm.notebook import tqdm
from einops import rearrange, repeat
from einops.layers.torch import Rearrange

# %%
print(f"Torch: {torch.__version__}")
# Out:
# Torch: 1.8.1+cu101

# %%
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True

seed_everything(11785)

# %%
device = 'cuda'

# %%
img_size = ((64, 64)) 

transforms_train = transforms.Compose([
    transforms.Resize(img_size),
    transforms.ColorJitter(hue=.05, saturation=.05),
    transforms.RandomHorizontalFlip(p=0.3),
    transforms.RandomVerticalFlip(p=0.3),
    transforms.RandomRotation(10, interpolation=torchvision.transforms.InterpolationMode.BILINEAR),
    transforms.RandomCrop(img_size, fill=0),
    transforms.RandomAffine(10, scale=(0.8, 1.2)),
    transforms.ToTensor(),
    transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))
])

transforms_val = transforms.Compose([
    transforms.Resize(img_size),
    transforms.ToTensor(),
    transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))
])

# %% [markdown]
# ## Load Data

# %%
train_data = torchvision.datasets.CIFAR10(train=True,download=True,root= "./cifar10/train_data", transform=transforms_train)
train_loader = torch.utils.data.DataLoader(train_data, batch_size=128,
                                          shuffle=True, num_workers=8)

valid_data = torchvision.datasets.CIFAR10(train=False,download=True,root= "./cifar10/test_data", transform=transforms_val)
valid_loader = torch.utils.data.DataLoader(valid_data, batch_size=32,
                                         shuffle=False, num_workers=8)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./cifar10/train_data/cifar-10-python.tar.gz
# HBox(children=(FloatProgress(value=0.0, max=170498071.0), HTML(value='')))
# Extracting ./cifar10/train_data/cifar-10-python.tar.gz to ./cifar10/train_data
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./cifar10/test_data/cifar-10-python.tar.gz
# HBox(children=(FloatProgress(value=0.0, max=170498071.0), HTML(value='')))
# Extracting ./cifar10/test_data/cifar-10-python.tar.gz to ./cifar10/test_data

# %%
print(len(train_data), len(train_loader))
# Out:
# 50000 391

# %%
print(len(valid_data), len(valid_loader))
# Out:
# 10000 313

# %% [markdown]
# ### Visual Transformer

# %%
class PreNorm(nn.Module):
    def __init__(self, dim, fn):
        super().__init__()
        self.norm = nn.LayerNorm(dim)
        self.fn = fn
    def forward(self, x, **kwargs):
        return self.fn(self.norm(x), **kwargs)

class FeedForward(nn.Module):
    def __init__(self, dim, hidden_dim, dropout = 0.):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(dim, hidden_dim),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(hidden_dim, dim),
            nn.Dropout(dropout)
        )
    def forward(self, x):
        return self.net(x)

class Attention(nn.Module):
    def __init__(self, dim, heads = 8, dim_head = 64, dropout = 0.):
        super().__init__()
        inner_dim = dim_head *  heads
        project_out = not (heads == 1 and dim_head == dim)

        self.heads = heads
        self.scale = dim_head ** -0.5

        self.attend = nn.Softmax(dim = -1)
        self.to_qkv = nn.Linear(dim, inner_dim * 3, bias = False)

        self.to_out = nn.Sequential(
            nn.Linear(inner_dim, dim),
            nn.Dropout(dropout)
        ) if project_out else nn.Identity()

    def forward(self, x):
        b, n, _, h = *x.shape, self.heads
        qkv = self.to_qkv(x).chunk(3, dim = -1)
        q, k, v = map(lambda t: rearrange(t, 'b n (h d) -> b h n d', h = h), qkv)

        dots = einsum('b h i d, b h j d -> b h i j', q, k) * self.scale

        attn = self.attend(dots)

        out = einsum('b h i j, b h j d -> b h i d', attn, v)
        out = rearrange(out, 'b h n d -> b n (h d)')
        return self.to_out(out)

class Transformer(nn.Module):
    def __init__(self, dim, depth, heads, dim_head, mlp_dim, dropout = 0.):
        super().__init__()
        self.layers = nn.ModuleList([])
        for _ in range(depth):
            self.layers.append(nn.ModuleList([
                PreNorm(dim, Attention(dim, heads = heads, dim_head = dim_head, dropout = dropout)),
                PreNorm(dim, FeedForward(dim, mlp_dim, dropout = dropout))
            ]))
    def forward(self, x):
        for attn, ff in self.layers:
            x = attn(x) + x
            x = ff(x) + x
        return x

class ViT(nn.Module):
    def __init__(self, *, image_size, patch_size, num_classes, dim, depth, heads, mlp_dim, pool = 'cls', channels = 3, dim_head = 64, dropout = 0., emb_dropout = 0.):
        super().__init__()
        assert image_size % patch_size == 0, 'Image dimensions must be divisible by the patch size.'
        num_patches = (image_size // patch_size) ** 2
        patch_dim = channels * patch_size ** 2
        assert pool in {'cls', 'mean'}, 'pool type must be either cls (cls token) or mean (mean pooling)'

        self.to_patch_embedding = nn.Sequential(
            Rearrange('b c (h p1) (w p2) -> b (h w) (p1 p2 c)', p1 = patch_size, p2 = patch_size),
            nn.Linear(patch_dim, dim),
        )

        self.pos_embedding = nn.Parameter(torch.randn(1, num_patches + 1, dim))
        self.cls_token = nn.Parameter(torch.randn(1, 1, dim))
        self.dropout = nn.Dropout(emb_dropout)

        self.transformer = Transformer(dim, depth, heads, dim_head, mlp_dim, dropout)

        self.pool = pool
        self.to_latent = nn.Identity()

        self.mlp_head = nn.Sequential(
            nn.LayerNorm(dim),
            nn.Linear(dim, num_classes)
        )

    def forward(self, img):
        x = self.to_patch_embedding(img)
        b, n, _ = x.shape

        cls_tokens = repeat(self.cls_token, '() n d -> b n d', b = b)
        x = torch.cat((cls_tokens, x), dim=1)
        x += self.pos_embedding[:, :(n + 1)]
        x = self.dropout(x)

        x = self.transformer(x)

        x = x.mean(dim = 1) if self.pool == 'mean' else x[:, 0]

        x = self.to_latent(x)
        return self.mlp_head(x)

# %%
model = ViT(
    image_size=64,
    patch_size=8,
    num_classes=10,
    dim=512,
    depth=6,
    heads=8,
    mlp_dim=1024,
    dropout=0.2,
    emb_dropout=0.1
).to(device)

# %% [markdown]
# ### Training

# %%
numEpochs = 100
in_features = 3 # RGB channels

learningRate = 0.03
weightDecay = 5e-5

num_classes = len(train_data.classes)

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=learningRate, weight_decay=weightDecay, momentum=0.9, nesterov=True)

scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='max', factor=0.3, patience=3, threshold=0.002, verbose=True)

# %%
my_acc = []
my_loss = []

# %%
# Train!
for epoch in range(numEpochs):
    
    # Train
    model.train()
    train_loss = 0.0
    train_acc = 0.0
    correct = 0

    for batch_num, (x, y) in enumerate(train_loader):
        optimizer.zero_grad()
        
        x, y = x.to(device), y.to(device)

        outputs = model(x)

        correct += (torch.argmax(outputs, axis=1) == y).sum().item()

        loss = criterion(outputs, y.long())
        loss.backward()
        optimizer.step()

        del(outputs)

        train_loss += loss.item()

        if batch_num % 100 == 0:
            print('Epoch: {}\tBatch: {}\tAvg-Loss: {:.4f}'.format(epoch, batch_num+1, train_loss/(batch_num+1)))

    train_accuracy = correct / len(train_data)

    # Validate
    model.eval()
    num_correct = 0
    for batch_num1, (x, y) in enumerate(valid_loader):
        x, y = x.to(device), y.to(device)
        outputs = model(x)

        num_correct += (torch.argmax(outputs, axis=1) == y).sum().item()

    val_accuracy = num_correct / len(valid_data)
    my_acc.append(val_accuracy)
    my_loss.append(train_loss/(batch_num+1))
    print('Epoch: {}\t Training Accuracy: {:.4f}\t Validation Accuracy: {:.4f}\t Avg-Loss: {:.4f}'.format(epoch, train_accuracy*100, val_accuracy * 100, train_loss/(batch_num+1)))
    scheduler.step(val_accuracy)

    #torch.save(network.state_dict(),'/content/drive/MyDrive/DL_CMU/HW2_P2/ResNet_Plateau_d3/Net_'+str(epoch)+'_'+str(val_accuracy)+'_checkpoint.t7')
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Epoch: 0	Batch: 1	Avg-Loss: 2.4225
# Epoch: 0	Batch: 101	Avg-Loss: 3.2220
# Epoch: 0	Batch: 201	Avg-Loss: 2.6791
# Epoch: 0	Batch: 301	Avg-Loss: 2.4711
# Epoch: 0	 Training Accuracy: 21.6080	 Validation Accuracy: 30.4100	 Avg-Loss: 2.3525
# Epoch: 1	Batch: 1	Avg-Loss: 1.8711
# Epoch: 1	Batch: 101	Avg-Loss: 1.8781
# Epoch: 1	Batch: 201	Avg-Loss: 1.8455
# Epoch: 1	Batch: 301	Avg-Loss: 1.8156
# Epoch: 1	 Training Accuracy: 34.1600	 Validation Accuracy: 41.2900	 Avg-Loss: 1.7890
# Epoch: 2	Batch: 1	Avg-Loss: 1.7566
# Epoch: 2	Batch: 101	Avg-Loss: 1.6584
# Epoch: 2	Batch: 201	Avg-Loss: 1.6391
# Epoch: 2	Batch: 301	Avg-Loss: 1.6276
# Epoch: 2	 Training Accuracy: 40.8920	 Validation Accuracy: 46.0900	 Avg-Loss: 1.6157
# Epoch: 3	Batch: 1	Avg-Loss: 1.6257
# Epoch: 3	Batch: 101	Avg-Loss: 1.5394
# Epoch: 3	Batch: 201	Avg-Loss: 1.5356
# Epoch: 3	Batch: 301	Avg-Loss: 1.5287
# Epoch: 3	 Training Accuracy: 44.5060	 Validation Accuracy: 48.1000	 Avg-Loss: 1.5235
# Epoch: 4	Batch: 1	Avg-Loss: 1.6012
# Epoch: 4	Batch: 101	Avg-Loss: 1.4790
# Epoch: 4	Batch: 201	Avg-Loss: 1.4750
# Epoch: 4	Batch: 301	Avg-Loss: 1.4668
# Epoch: 4	 Training Accuracy: 46.8280	 Validation Accuracy: 52.6600	 Avg-Loss: 1.4610
# Epoch: 5	Batch: 1	Avg-Loss: 1.4633
# Epoch: 5	Batch: 101	Avg-Loss: 1.4152
# Epoch: 5	Batch: 201	Avg-Loss: 1.4074
# Epoch: 5	Batch: 301	Avg-Loss: 1.4037
# Epoch: 5	 Training Accuracy: 49.0980	 Validation Accuracy: 54.3600	 Avg-Loss: 1.4009
# Epoch: 6	Batch: 1	Avg-Loss: 1.2751
# Epoch: 6	Batch: 101	Avg-Loss: 1.3665
# Epoch: 6	Batch: 201	Avg-Loss: 1.3591
# Epoch: 6	Batch: 301	Avg-Loss: 1.3576
# Epoch: 6	 Training Accuracy: 51.0780	 Validation Accuracy: 54.5800	 Avg-Loss: 1.3561
# Epoch: 7	Batch: 1	Avg-Loss: 1.3085
# Epoch: 7	Batch: 101	Avg-Loss: 1.3259
# Epoch: 7	Batch: 201	Avg-Loss: 1.3219
# Epoch: 7	Batch: 301	Avg-Loss: 1.3210
# Epoch: 7	 Training Accuracy: 52.5200	 Validation Accuracy: 57.2800	 Avg-Loss: 1.3179
# Epoch: 8	Batch: 1	Avg-Loss: 1.4053
# Epoch: 8	Batch: 101	Avg-Loss: 1.2864
# Epoch: 8	Batch: 201	Avg-Loss: 1.2884
# Epoch: 8	Batch: 301	Avg-Loss: 1.2837
# Epoch: 8	 Training Accuracy: 53.9480	 Validation Accuracy: 58.1800	 Avg-Loss: 1.2823
# Epoch: 9	Batch: 1	Avg-Loss: 1.2649
# Epoch: 9	Batch: 101	Avg-Loss: 1.2721
# Epoch: 9	Batch: 201	Avg-Loss: 1.2603
# Epoch: 9	Batch: 301	Avg-Loss: 1.2516
# Epoch: 9	 Training Accuracy: 55.0520	 Validation Accuracy: 58.7000	 Avg-Loss: 1.2474
# Epoch: 10	Batch: 1	Avg-Loss: 1.3093
# Epoch: 10	Batch: 101	Avg-Loss: 1.2346
# Epoch: 10	Batch: 201	Avg-Loss: 1.2313
# Epoch: 10	Batch: 301	Avg-Loss: 1.2320
# Epoch: 10	 Training Accuracy: 56.3300	 Validation Accuracy: 59.6000	 Avg-Loss: 1.2226
# Epoch: 11	Batch: 1	Avg-Loss: 1.1914
# Epoch: 11	Batch: 101	Avg-Loss: 1.2043
# Epoch: 11	Batch: 201	Avg-Loss: 1.1996
# Epoch: 11	Batch: 301	Avg-Loss: 1.1976
# Epoch: 11	 Training Accuracy: 57.0940	 Validation Accuracy: 59.6900	 Avg-Loss: 1.1970
# Epoch: 12	Batch: 1	Avg-Loss: 1.0939
# Epoch: 12	Batch: 101	Avg-Loss: 1.1650
# Epoch: 12	Batch: 201	Avg-Loss: 1.1778
# Epoch: 12	Batch: 301	Avg-Loss: 1.1748
# Epoch: 12	 Training Accuracy: 58.0200	 Validation Accuracy: 60.2400	 Avg-Loss: 1.1759
# Epoch: 13	Batch: 1	Avg-Loss: 1.1544
# Epoch: 13	Batch: 101	Avg-Loss: 1.1457
# Epoch: 13	Batch: 201	Avg-Loss: 1.1553
# Epoch: 13	Batch: 301	Avg-Loss: 1.1497
# Epoch: 13	 Training Accuracy: 58.6780	 Validation Accuracy: 61.3900	 Avg-Loss: 1.1499
# Epoch: 14	Batch: 1	Avg-Loss: 1.0414
# Epoch: 14	Batch: 101	Avg-Loss: 1.1406
# Epoch: 14	Batch: 201	Avg-Loss: 1.1386
# Epoch: 14	Batch: 301	Avg-Loss: 1.1425
# Epoch: 14	 Training Accuracy: 59.4260	 Validation Accuracy: 62.8600	 Avg-Loss: 1.1359
# Epoch: 15	Batch: 1	Avg-Loss: 1.2519
# Epoch: 15	Batch: 101	Avg-Loss: 1.1157
# Epoch: 15	Batch: 201	Avg-Loss: 1.1143
# Epoch: 15	Batch: 301	Avg-Loss: 1.1108
# Epoch: 15	 Training Accuracy: 60.6020	 Validation Accuracy: 61.6900	 Avg-Loss: 1.1114
# Epoch: 16	Batch: 1	Avg-Loss: 1.3495
# Epoch: 16	Batch: 101	Avg-Loss: 1.1010
# Epoch: 16	Batch: 201	Avg-Loss: 1.0982
# Epoch: 16	Batch: 301	Avg-Loss: 1.0995
# Epoch: 16	 Training Accuracy: 60.8980	 Validation Accuracy: 62.7200	 Avg-Loss: 1.0992
# Epoch: 17	Batch: 1	Avg-Loss: 1.2068
# Epoch: 17	Batch: 101	Avg-Loss: 1.0864
# Epoch: 17	Batch: 201	Avg-Loss: 1.0834
# Epoch: 17	Batch: 301	Avg-Loss: 1.0836
# Epoch: 17	 Training Accuracy: 61.5160	 Validation Accuracy: 62.9900	 Avg-Loss: 1.0825
# Epoch: 18	Batch: 1	Avg-Loss: 1.0610
# Epoch: 18	Batch: 101	Avg-Loss: 1.0556
# Epoch: 18	Batch: 201	Avg-Loss: 1.0661
# Epoch: 18	Batch: 301	Avg-Loss: 1.0667
# Epoch: 18	 Training Accuracy: 61.9160	 Validation Accuracy: 64.2700	 Avg-Loss: 1.0648
# Epoch: 19	Batch: 1	Avg-Loss: 0.8767
# Epoch: 19	Batch: 101	Avg-Loss: 1.0413
# Epoch: 19	Batch: 201	Avg-Loss: 1.0561
# Epoch: 19	Batch: 301	Avg-Loss: 1.0498
# Epoch: 19	 Training Accuracy: 62.7720	 Validation Accuracy: 64.5400	 Avg-Loss: 1.0488
# Epoch: 20	Batch: 1	Avg-Loss: 0.9461
# Epoch: 20	Batch: 101	Avg-Loss: 1.0223
# Epoch: 20	Batch: 201	Avg-Loss: 1.0215
# Epoch: 20	Batch: 301	Avg-Loss: 1.0246
# Epoch: 20	 Training Accuracy: 63.2080	 Validation Accuracy: 65.9400	 Avg-Loss: 1.0311
# Epoch: 21	Batch: 1	Avg-Loss: 0.9741
# Epoch: 21	Batch: 101	Avg-Loss: 1.0237
# Epoch: 21	Batch: 201	Avg-Loss: 1.0204
# Epoch: 21	Batch: 301	Avg-Loss: 1.0245
# Epoch: 21	 Training Accuracy: 63.3580	 Validation Accuracy: 66.1900	 Avg-Loss: 1.0274
# Epoch: 22	Batch: 1	Avg-Loss: 0.8284
# Epoch: 22	Batch: 101	Avg-Loss: 1.0027
# Epoch: 22	Batch: 201	Avg-Loss: 0.9986
# Epoch: 22	Batch: 301	Avg-Loss: 1.0065
# Epoch: 22	 Training Accuracy: 64.0140	 Validation Accuracy: 67.0100	 Avg-Loss: 1.0069
# Epoch: 23	Batch: 1	Avg-Loss: 0.9781
# Epoch: 23	Batch: 101	Avg-Loss: 0.9918
# Epoch: 23	Batch: 201	Avg-Loss: 0.9974
# Epoch: 23	Batch: 301	Avg-Loss: 1.0032
# Epoch: 23	 Training Accuracy: 64.3820	 Validation Accuracy: 65.4900	 Avg-Loss: 0.9971
# Epoch: 24	Batch: 1	Avg-Loss: 1.0085
# Epoch: 24	Batch: 101	Avg-Loss: 0.9788
# Epoch: 24	Batch: 201	Avg-Loss: 0.9769
# Epoch: 24	Batch: 301	Avg-Loss: 0.9801
# Epoch: 24	 Training Accuracy: 65.1300	 Validation Accuracy: 66.9400	 Avg-Loss: 0.9795
# Epoch: 25	Batch: 1	Avg-Loss: 0.9461
# Epoch: 25	Batch: 101	Avg-Loss: 0.9577
# Epoch: 25	Batch: 201	Avg-Loss: 0.9652
# Epoch: 25	Batch: 301	Avg-Loss: 0.9657
# Epoch: 25	 Training Accuracy: 65.7400	 Validation Accuracy: 67.7300	 Avg-Loss: 0.9687
# Epoch: 26	Batch: 1	Avg-Loss: 0.8986
# Epoch: 26	Batch: 101	Avg-Loss: 0.9564
# Epoch: 26	Batch: 201	Avg-Loss: 0.9471
# Epoch: 26	Batch: 301	Avg-Loss: 0.9502
# Epoch: 26	 Training Accuracy: 66.0400	 Validation Accuracy: 68.8800	 Avg-Loss: 0.9529
# Epoch: 27	Batch: 1	Avg-Loss: 0.7199
# Epoch: 27	Batch: 101	Avg-Loss: 0.9438
# Epoch: 27	Batch: 201	Avg-Loss: 0.9488
# Epoch: 27	Batch: 301	Avg-Loss: 0.9464
# Epoch: 27	 Training Accuracy: 66.4840	 Validation Accuracy: 67.2400	 Avg-Loss: 0.9450
# Epoch: 28	Batch: 1	Avg-Loss: 0.8665
# Epoch: 28	Batch: 101	Avg-Loss: 0.9348
# Epoch: 28	Batch: 201	Avg-Loss: 0.9315
# Epoch: 28	Batch: 301	Avg-Loss: 0.9366
# Epoch: 28	 Training Accuracy: 66.6040	 Validation Accuracy: 67.5700	 Avg-Loss: 0.9349
# Epoch: 29	Batch: 1	Avg-Loss: 1.0357
# Epoch: 29	Batch: 101	Avg-Loss: 0.9249
# Epoch: 29	Batch: 201	Avg-Loss: 0.9214
# Epoch: 29	Batch: 301	Avg-Loss: 0.9235
# Epoch: 29	 Training Accuracy: 66.8600	 Validation Accuracy: 68.3000	 Avg-Loss: 0.9232
# Epoch: 30	Batch: 1	Avg-Loss: 0.8644
# Epoch: 30	Batch: 101	Avg-Loss: 0.9081
# Epoch: 30	Batch: 201	Avg-Loss: 0.9162
# Epoch: 30	Batch: 301	Avg-Loss: 0.9129
# Epoch: 30	 Training Accuracy: 67.6260	 Validation Accuracy: 69.1500	 Avg-Loss: 0.9105
# Epoch: 31	Batch: 1	Avg-Loss: 0.9557
# Epoch: 31	Batch: 101	Avg-Loss: 0.8847
# Epoch: 31	Batch: 201	Avg-Loss: 0.8940
# Epoch: 31	Batch: 301	Avg-Loss: 0.9020
# Epoch: 31	 Training Accuracy: 67.6440	 Validation Accuracy: 69.2900	 Avg-Loss: 0.9024
# Epoch: 32	Batch: 1	Avg-Loss: 0.7846
# Epoch: 32	Batch: 101	Avg-Loss: 0.8867
# Epoch: 32	Batch: 201	Avg-Loss: 0.8839
# Epoch: 32	Batch: 301	Avg-Loss: 0.8881
# Epoch: 32	 Training Accuracy: 68.2760	 Validation Accuracy: 69.1000	 Avg-Loss: 0.8899
# Epoch: 33	Batch: 1	Avg-Loss: 0.8977
# Epoch: 33	Batch: 101	Avg-Loss: 0.8767
# Epoch: 33	Batch: 201	Avg-Loss: 0.8818
# Epoch: 33	Batch: 301	Avg-Loss: 0.8821
# Epoch: 33	 Training Accuracy: 68.8180	 Validation Accuracy: 69.0900	 Avg-Loss: 0.8836
# Epoch: 34	Batch: 1	Avg-Loss: 0.8860
# Epoch: 34	Batch: 101	Avg-Loss: 0.8522
# Epoch: 34	Batch: 201	Avg-Loss: 0.8628
# Epoch: 34	Batch: 301	Avg-Loss: 0.8700
# Epoch: 34	 Training Accuracy: 69.0740	 Validation Accuracy: 70.6200	 Avg-Loss: 0.8730
# Epoch: 35	Batch: 1	Avg-Loss: 0.8542
# Epoch: 35	Batch: 101	Avg-Loss: 0.8566
# Epoch: 35	Batch: 201	Avg-Loss: 0.8577
# Epoch: 35	Batch: 301	Avg-Loss: 0.8612
# Epoch: 35	 Training Accuracy: 69.3300	 Validation Accuracy: 70.5500	 Avg-Loss: 0.8616
# Epoch: 36	Batch: 1	Avg-Loss: 0.8319
# Epoch: 36	Batch: 101	Avg-Loss: 0.8497
# Epoch: 36	Batch: 201	Avg-Loss: 0.8480
# Epoch: 36	Batch: 301	Avg-Loss: 0.8511
# Epoch: 36	 Training Accuracy: 69.8460	 Validation Accuracy: 70.5900	 Avg-Loss: 0.8537
# Epoch: 37	Batch: 1	Avg-Loss: 0.8909
# Epoch: 37	Batch: 101	Avg-Loss: 0.8514
# Epoch: 37	Batch: 201	Avg-Loss: 0.8364
# Epoch: 37	Batch: 301	Avg-Loss: 0.8438
# Epoch: 37	 Training Accuracy: 70.3060	 Validation Accuracy: 71.5800	 Avg-Loss: 0.8397
# Epoch: 38	Batch: 1	Avg-Loss: 0.7275
# Epoch: 38	Batch: 101	Avg-Loss: 0.8260
# Epoch: 38	Batch: 201	Avg-Loss: 0.8352
# Epoch: 38	Batch: 301	Avg-Loss: 0.8375
# Epoch: 38	 Training Accuracy: 70.0460	 Validation Accuracy: 71.3800	 Avg-Loss: 0.8374
# Epoch: 39	Batch: 1	Avg-Loss: 0.7837
# Epoch: 39	Batch: 101	Avg-Loss: 0.8132
# Epoch: 39	Batch: 201	Avg-Loss: 0.8202
# Epoch: 39	Batch: 301	Avg-Loss: 0.8219
# Epoch: 39	 Training Accuracy: 70.5800	 Validation Accuracy: 70.6600	 Avg-Loss: 0.8249
# Epoch: 40	Batch: 1	Avg-Loss: 0.6558
# Epoch: 40	Batch: 101	Avg-Loss: 0.8032
# Epoch: 40	Batch: 201	Avg-Loss: 0.8060
# Epoch: 40	Batch: 301	Avg-Loss: 0.8109
# Epoch: 40	 Training Accuracy: 71.0140	 Validation Accuracy: 70.8000	 Avg-Loss: 0.8141
# Epoch: 41	Batch: 1	Avg-Loss: 0.7238
# Epoch: 41	Batch: 101	Avg-Loss: 0.8034
# Epoch: 41	Batch: 201	Avg-Loss: 0.8008
# Epoch: 41	Batch: 301	Avg-Loss: 0.8015
# Epoch: 41	 Training Accuracy: 71.3100	 Validation Accuracy: 72.1100	 Avg-Loss: 0.8041
# Epoch: 42	Batch: 1	Avg-Loss: 0.8227
# Epoch: 42	Batch: 101	Avg-Loss: 0.7871
# Epoch: 42	Batch: 201	Avg-Loss: 0.7954
# Epoch: 42	Batch: 301	Avg-Loss: 0.7978
# Epoch: 42	 Training Accuracy: 71.5540	 Validation Accuracy: 71.7900	 Avg-Loss: 0.7998
# Epoch: 43	Batch: 1	Avg-Loss: 0.8430
# Epoch: 43	Batch: 101	Avg-Loss: 0.7908
# Epoch: 43	Batch: 201	Avg-Loss: 0.7930
# Epoch: 43	Batch: 301	Avg-Loss: 0.7887
# Epoch: 43	 Training Accuracy: 72.0260	 Validation Accuracy: 72.0400	 Avg-Loss: 0.7877
# Epoch: 44	Batch: 1	Avg-Loss: 0.7177
# Epoch: 44	Batch: 101	Avg-Loss: 0.7726
# Epoch: 44	Batch: 201	Avg-Loss: 0.7762
# Epoch: 44	Batch: 301	Avg-Loss: 0.7784
# Epoch: 44	 Training Accuracy: 72.4020	 Validation Accuracy: 72.9800	 Avg-Loss: 0.7807
# Epoch: 45	Batch: 1	Avg-Loss: 0.7044
# Epoch: 45	Batch: 101	Avg-Loss: 0.7641
# Epoch: 45	Batch: 201	Avg-Loss: 0.7626
# Epoch: 45	Batch: 301	Avg-Loss: 0.7662
# Epoch: 45	 Training Accuracy: 72.4840	 Validation Accuracy: 73.3300	 Avg-Loss: 0.7696
# Epoch: 46	Batch: 1	Avg-Loss: 0.8496
# Epoch: 46	Batch: 101	Avg-Loss: 0.7503
# Epoch: 46	Batch: 201	Avg-Loss: 0.7568
# Epoch: 46	Batch: 301	Avg-Loss: 0.7637
# Epoch: 46	 Training Accuracy: 72.7920	 Validation Accuracy: 71.5600	 Avg-Loss: 0.7649
# Epoch: 47	Batch: 1	Avg-Loss: 0.7858
# Epoch: 47	Batch: 101	Avg-Loss: 0.7594
# Epoch: 47	Batch: 201	Avg-Loss: 0.7505
# Epoch: 47	Batch: 301	Avg-Loss: 0.7561
# Epoch: 47	 Training Accuracy: 73.0760	 Validation Accuracy: 72.6600	 Avg-Loss: 0.7551
# Epoch: 48	Batch: 1	Avg-Loss: 0.8349
# Epoch: 48	Batch: 101	Avg-Loss: 0.7565
# Epoch: 48	Batch: 201	Avg-Loss: 0.7473
# Epoch: 48	Batch: 301	Avg-Loss: 0.7493
# Epoch: 48	 Training Accuracy: 73.3880	 Validation Accuracy: 73.3400	 Avg-Loss: 0.7513
# Epoch: 49	Batch: 1	Avg-Loss: 0.7098
# Epoch: 49	Batch: 101	Avg-Loss: 0.7403
# Epoch: 49	Batch: 201	Avg-Loss: 0.7391
# Epoch: 49	Batch: 301	Avg-Loss: 0.7389
# Epoch: 49	 Training Accuracy: 73.4520	 Validation Accuracy: 72.5500	 Avg-Loss: 0.7406
# Epoch    50: reducing learning rate of group 0 to 9.0000e-03.
# Epoch: 50	Batch: 1	Avg-Loss: 0.9323
# Epoch: 50	Batch: 101	Avg-Loss: 0.6752
# Epoch: 50	Batch: 201	Avg-Loss: 0.6651
# Epoch: 50	Batch: 301	Avg-Loss: 0.6631
# Epoch: 50	 Training Accuracy: 76.4000	 Validation Accuracy: 75.3600	 Avg-Loss: 0.6624
# Epoch: 51	Batch: 1	Avg-Loss: 0.7622
# Epoch: 51	Batch: 101	Avg-Loss: 0.6334
# Epoch: 51	Batch: 201	Avg-Loss: 0.6375
# Epoch: 51	Batch: 301	Avg-Loss: 0.6435
# Epoch: 51	 Training Accuracy: 77.0520	 Validation Accuracy: 74.8400	 Avg-Loss: 0.6437
# Epoch: 52	Batch: 1	Avg-Loss: 0.6689
# Epoch: 52	Batch: 101	Avg-Loss: 0.6302
# Epoch: 52	Batch: 201	Avg-Loss: 0.6305
# Epoch: 52	Batch: 301	Avg-Loss: 0.6307
# Epoch: 52	 Training Accuracy: 77.5900	 Validation Accuracy: 75.7300	 Avg-Loss: 0.6319
# Epoch: 53	Batch: 1	Avg-Loss: 0.7484
# Epoch: 53	Batch: 101	Avg-Loss: 0.6131
# Epoch: 53	Batch: 201	Avg-Loss: 0.6209
# Epoch: 53	Batch: 301	Avg-Loss: 0.6176
# Epoch: 53	 Training Accuracy: 77.9140	 Validation Accuracy: 75.1700	 Avg-Loss: 0.6207
# Epoch: 54	Batch: 1	Avg-Loss: 0.6463
# Epoch: 54	Batch: 101	Avg-Loss: 0.6153
# Epoch: 54	Batch: 201	Avg-Loss: 0.6118
# Epoch: 54	Batch: 301	Avg-Loss: 0.6146
# Epoch: 54	 Training Accuracy: 78.0220	 Validation Accuracy: 75.5100	 Avg-Loss: 0.6183
# Epoch: 55	Batch: 1	Avg-Loss: 0.5915
# Epoch: 55	Batch: 101	Avg-Loss: 0.6099
# Epoch: 55	Batch: 201	Avg-Loss: 0.6075
# Epoch: 55	Batch: 301	Avg-Loss: 0.6070
# Epoch: 55	 Training Accuracy: 78.4160	 Validation Accuracy: 75.1400	 Avg-Loss: 0.6058
# Epoch: 56	Batch: 1	Avg-Loss: 0.6317
# Epoch: 56	Batch: 101	Avg-Loss: 0.6042
# Epoch: 56	Batch: 201	Avg-Loss: 0.5964
# Epoch: 56	Batch: 301	Avg-Loss: 0.6021
# Epoch: 56	 Training Accuracy: 78.6320	 Validation Accuracy: 75.6900	 Avg-Loss: 0.6048
# Epoch    57: reducing learning rate of group 0 to 2.7000e-03.
# Epoch: 57	Batch: 1	Avg-Loss: 0.5499
# Epoch: 57	Batch: 101	Avg-Loss: 0.5721
# Epoch: 57	Batch: 201	Avg-Loss: 0.5733
# Epoch: 57	Batch: 301	Avg-Loss: 0.5692
# Epoch: 57	 Training Accuracy: 79.5100	 Validation Accuracy: 76.1000	 Avg-Loss: 0.5723
# Epoch: 58	Batch: 1	Avg-Loss: 0.5837
# Epoch: 58	Batch: 101	Avg-Loss: 0.5640
# Epoch: 58	Batch: 201	Avg-Loss: 0.5662
# Epoch: 58	Batch: 301	Avg-Loss: 0.5607
# Epoch: 58	 Training Accuracy: 80.0440	 Validation Accuracy: 76.2600	 Avg-Loss: 0.5620
# Epoch: 59	Batch: 1	Avg-Loss: 0.6607
# Epoch: 59	Batch: 101	Avg-Loss: 0.5531
# Epoch: 59	Batch: 201	Avg-Loss: 0.5512
# Epoch: 59	Batch: 301	Avg-Loss: 0.5588
# Epoch: 59	 Training Accuracy: 80.2020	 Validation Accuracy: 76.0300	 Avg-Loss: 0.5581
# Epoch: 60	Batch: 1	Avg-Loss: 0.5566
# Epoch: 60	Batch: 101	Avg-Loss: 0.5613
# Epoch: 60	Batch: 201	Avg-Loss: 0.5611
# Epoch: 60	Batch: 301	Avg-Loss: 0.5596
# Epoch: 60	 Training Accuracy: 80.1940	 Validation Accuracy: 76.1400	 Avg-Loss: 0.5590
# Epoch: 61	Batch: 1	Avg-Loss: 0.6172
# Epoch: 61	Batch: 101	Avg-Loss: 0.5580
# Epoch: 61	Batch: 201	Avg-Loss: 0.5566
# Epoch: 61	Batch: 301	Avg-Loss: 0.5572
# Epoch: 61	 Training Accuracy: 80.1060	 Validation Accuracy: 76.3500	 Avg-Loss: 0.5549
# Epoch: 62	Batch: 1	Avg-Loss: 0.5628
# Epoch: 62	Batch: 101	Avg-Loss: 0.5550
# Epoch: 62	Batch: 201	Avg-Loss: 0.5585
# Epoch: 62	Batch: 301	Avg-Loss: 0.5514
# Epoch: 62	 Training Accuracy: 80.2120	 Validation Accuracy: 76.0900	 Avg-Loss: 0.5509
# Epoch    63: reducing learning rate of group 0 to 8.1000e-04.
# Epoch: 63	Batch: 1	Avg-Loss: 0.5344
# Epoch: 63	Batch: 101	Avg-Loss: 0.5287
# Epoch: 63	Batch: 201	Avg-Loss: 0.5314
# Epoch: 63	Batch: 301	Avg-Loss: 0.5308
# Epoch: 63	 Training Accuracy: 80.8280	 Validation Accuracy: 76.1000	 Avg-Loss: 0.5382
# Epoch: 64	Batch: 1	Avg-Loss: 0.6794
# Epoch: 64	Batch: 101	Avg-Loss: 0.5327
# Epoch: 64	Batch: 201	Avg-Loss: 0.5341
# Epoch: 64	Batch: 301	Avg-Loss: 0.5341
# Epoch: 64	 Training Accuracy: 80.9420	 Validation Accuracy: 76.2500	 Avg-Loss: 0.5365
# Epoch: 65	Batch: 1	Avg-Loss: 0.5099
# Epoch: 65	Batch: 101	Avg-Loss: 0.5346
# Epoch: 65	Batch: 201	Avg-Loss: 0.5341
# Epoch: 65	Batch: 301	Avg-Loss: 0.5378
# Epoch: 65	 Training Accuracy: 80.8060	 Validation Accuracy: 76.2200	 Avg-Loss: 0.5380
# Epoch: 66	Batch: 1	Avg-Loss: 0.6642
# Epoch: 66	Batch: 101	Avg-Loss: 0.5327
# Epoch: 66	Batch: 201	Avg-Loss: 0.5312
# Epoch: 66	Batch: 301	Avg-Loss: 0.5371
# Epoch: 66	 Training Accuracy: 80.8400	 Validation Accuracy: 76.1100	 Avg-Loss: 0.5336
# Epoch    67: reducing learning rate of group 0 to 2.4300e-04.
# Epoch: 67	Batch: 1	Avg-Loss: 0.5692
# Epoch: 67	Batch: 101	Avg-Loss: 0.5277
# Epoch: 67	Batch: 201	Avg-Loss: 0.5286
# Epoch: 67	Batch: 301	Avg-Loss: 0.5233
# Epoch: 67	 Training Accuracy: 81.2660	 Validation Accuracy: 76.2000	 Avg-Loss: 0.5264
# Epoch: 68	Batch: 1	Avg-Loss: 0.5789
# Epoch: 68	Batch: 101	Avg-Loss: 0.5289
# Epoch: 68	Batch: 201	Avg-Loss: 0.5271
# Epoch: 68	Batch: 301	Avg-Loss: 0.5262
# Epoch: 68	 Training Accuracy: 81.0840	 Validation Accuracy: 76.2600	 Avg-Loss: 0.5286
# Epoch: 69	Batch: 1	Avg-Loss: 0.5666
# Epoch: 69	Batch: 101	Avg-Loss: 0.5171
# Epoch: 69	Batch: 201	Avg-Loss: 0.5211
# Epoch: 69	Batch: 301	Avg-Loss: 0.5265
# Epoch: 69	 Training Accuracy: 81.2660	 Validation Accuracy: 76.2200	 Avg-Loss: 0.5260
# Epoch: 70	Batch: 1	Avg-Loss: 0.5255
# Epoch: 70	Batch: 101	Avg-Loss: 0.5316
# Epoch: 70	Batch: 201	Avg-Loss: 0.5232
# Epoch: 70	Batch: 301	Avg-Loss: 0.5232
# Epoch: 70	 Training Accuracy: 81.1780	 Validation Accuracy: 76.2200	 Avg-Loss: 0.5274
# Epoch    71: reducing learning rate of group 0 to 7.2900e-05.
# Epoch: 71	Batch: 1	Avg-Loss: 0.4612
# Epoch: 71	Batch: 101	Avg-Loss: 0.5117
# Epoch: 71	Batch: 201	Avg-Loss: 0.5209
# Epoch: 71	Batch: 301	Avg-Loss: 0.5209
# Epoch: 71	 Training Accuracy: 81.3220	 Validation Accuracy: 76.2000	 Avg-Loss: 0.5232
# Epoch: 72	Batch: 1	Avg-Loss: 0.5456
# Epoch: 72	Batch: 101	Avg-Loss: 0.5304
# Epoch: 72	Batch: 201	Avg-Loss: 0.5242
# Epoch: 72	Batch: 301	Avg-Loss: 0.5255
# Epoch: 72	 Training Accuracy: 81.2100	 Validation Accuracy: 76.2100	 Avg-Loss: 0.5246
# Epoch: 73	Batch: 1	Avg-Loss: 0.6394
# Epoch: 73	Batch: 101	Avg-Loss: 0.5136
# Epoch: 73	Batch: 201	Avg-Loss: 0.5258
# Epoch: 73	Batch: 301	Avg-Loss: 0.5221
# Epoch: 73	 Training Accuracy: 81.3060	 Validation Accuracy: 76.2200	 Avg-Loss: 0.5243
# Epoch: 74	Batch: 1	Avg-Loss: 0.5102
# Epoch: 74	Batch: 101	Avg-Loss: 0.5218
# Epoch: 74	Batch: 201	Avg-Loss: 0.5202
# Epoch: 74	Batch: 301	Avg-Loss: 0.5201
# Epoch: 74	 Training Accuracy: 81.2180	 Validation Accuracy: 76.2400	 Avg-Loss: 0.5235
# Epoch    75: reducing learning rate of group 0 to 2.1870e-05.
# Epoch: 75	Batch: 1	Avg-Loss: 0.6158
# Epoch: 75	Batch: 101	Avg-Loss: 0.5449
# Epoch: 75	Batch: 201	Avg-Loss: 0.5348
# Epoch: 75	Batch: 301	Avg-Loss: 0.5317
# Epoch: 75	 Training Accuracy: 81.2180	 Validation Accuracy: 76.2600	 Avg-Loss: 0.5289
# Epoch: 76	Batch: 1	Avg-Loss: 0.4977
# Epoch: 76	Batch: 101	Avg-Loss: 0.5260
# Epoch: 76	Batch: 201	Avg-Loss: 0.5227
# Epoch: 76	Batch: 301	Avg-Loss: 0.5254
# Epoch: 76	 Training Accuracy: 81.1840	 Validation Accuracy: 76.2500	 Avg-Loss: 0.5253
# Epoch: 77	Batch: 1	Avg-Loss: 0.7825
# Epoch: 77	Batch: 101	Avg-Loss: 0.5290
# Epoch: 77	Batch: 201	Avg-Loss: 0.5284
# Epoch: 77	Batch: 301	Avg-Loss: 0.5272
# Epoch: 77	 Training Accuracy: 81.2180	 Validation Accuracy: 76.3000	 Avg-Loss: 0.5254
# Epoch: 78	Batch: 1	Avg-Loss: 0.5571
# Epoch: 78	Batch: 101	Avg-Loss: 0.5305
# Epoch: 78	Batch: 201	Avg-Loss: 0.5270
# Epoch: 78	Batch: 301	Avg-Loss: 0.5238
# Epoch: 78	 Training Accuracy: 81.2860	 Validation Accuracy: 76.3100	 Avg-Loss: 0.5241
# Epoch    79: reducing learning rate of group 0 to 6.5610e-06.
# Epoch: 79	Batch: 1	Avg-Loss: 0.5160
# Epoch: 79	Batch: 101	Avg-Loss: 0.5319
# Epoch: 79	Batch: 201	Avg-Loss: 0.5304
# Epoch: 79	Batch: 301	Avg-Loss: 0.5287
# Epoch: 79	 Training Accuracy: 81.3320	 Validation Accuracy: 76.3000	 Avg-Loss: 0.5264
# Epoch: 80	Batch: 1	Avg-Loss: 0.6358
# Epoch: 80	Batch: 101	Avg-Loss: 0.5150
# Epoch: 80	Batch: 201	Avg-Loss: 0.5159
# Epoch: 80	Batch: 301	Avg-Loss: 0.5183
# Epoch: 80	 Training Accuracy: 81.4220	 Validation Accuracy: 76.2900	 Avg-Loss: 0.5213
# Epoch: 81	Batch: 1	Avg-Loss: 0.4347
# Epoch: 81	Batch: 101	Avg-Loss: 0.5349
# Epoch: 81	Batch: 201	Avg-Loss: 0.5294
# Epoch: 81	Batch: 301	Avg-Loss: 0.5290
# Epoch: 81	 Training Accuracy: 81.2080	 Validation Accuracy: 76.2900	 Avg-Loss: 0.5281
# Epoch: 82	Batch: 1	Avg-Loss: 0.5349
# Epoch: 82	Batch: 101	Avg-Loss: 0.5422
# Epoch: 82	Batch: 201	Avg-Loss: 0.5377
# Epoch: 82	Batch: 301	Avg-Loss: 0.5308
# Epoch: 82	 Training Accuracy: 81.2580	 Validation Accuracy: 76.2400	 Avg-Loss: 0.5283
# Epoch    83: reducing learning rate of group 0 to 1.9683e-06.
# Epoch: 83	Batch: 1	Avg-Loss: 0.5574
# Epoch: 83	Batch: 101	Avg-Loss: 0.5377
# Epoch: 83	Batch: 201	Avg-Loss: 0.5330
# Epoch: 83	Batch: 301	Avg-Loss: 0.5256
# Epoch: 83	 Training Accuracy: 81.2440	 Validation Accuracy: 76.2400	 Avg-Loss: 0.5269
# Epoch: 84	Batch: 1	Avg-Loss: 0.4039
# Epoch: 84	Batch: 101	Avg-Loss: 0.5290
# Epoch: 84	Batch: 201	Avg-Loss: 0.5221
# Epoch: 84	Batch: 301	Avg-Loss: 0.5239
# Epoch: 84	 Training Accuracy: 81.2580	 Validation Accuracy: 76.2500	 Avg-Loss: 0.5243
# Epoch: 85	Batch: 1	Avg-Loss: 0.6529
# Epoch: 85	Batch: 101	Avg-Loss: 0.5200
# Epoch: 85	Batch: 201	Avg-Loss: 0.5275
# Epoch: 85	Batch: 301	Avg-Loss: 0.5227
# Epoch: 85	 Training Accuracy: 81.2580	 Validation Accuracy: 76.2500	 Avg-Loss: 0.5224
# Epoch: 86	Batch: 1	Avg-Loss: 0.5336
# Epoch: 86	Batch: 101	Avg-Loss: 0.5278
# Epoch: 86	Batch: 201	Avg-Loss: 0.5185
# Epoch: 86	Batch: 301	Avg-Loss: 0.5198
# Epoch: 86	 Training Accuracy: 81.5280	 Validation Accuracy: 76.2600	 Avg-Loss: 0.5216
# Epoch    87: reducing learning rate of group 0 to 5.9049e-07.
# Epoch: 87	Batch: 1	Avg-Loss: 0.5236
# Epoch: 87	Batch: 101	Avg-Loss: 0.5286
# Epoch: 87	Batch: 201	Avg-Loss: 0.5321
# Epoch: 87	Batch: 301	Avg-Loss: 0.5265
# Epoch: 87	 Training Accuracy: 81.1420	 Validation Accuracy: 76.2600	 Avg-Loss: 0.5266
# Epoch: 88	Batch: 1	Avg-Loss: 0.3920
# Epoch: 88	Batch: 101	Avg-Loss: 0.5260
# Epoch: 88	Batch: 201	Avg-Loss: 0.5266
# Epoch: 88	Batch: 301	Avg-Loss: 0.5279
# Epoch: 88	 Training Accuracy: 81.1620	 Validation Accuracy: 76.2600	 Avg-Loss: 0.5287
# Epoch: 89	Batch: 1	Avg-Loss: 0.5288
# Epoch: 89	Batch: 101	Avg-Loss: 0.5191
# Epoch: 89	Batch: 201	Avg-Loss: 0.5214
# Epoch: 89	Batch: 301	Avg-Loss: 0.5208
# Epoch: 89	 Training Accuracy: 81.4520	 Validation Accuracy: 76.2700	 Avg-Loss: 0.5228
# Epoch: 90	Batch: 1	Avg-Loss: 0.7460
# Epoch: 90	Batch: 101	Avg-Loss: 0.5228
# Epoch: 90	Batch: 201	Avg-Loss: 0.5212
# Epoch: 90	Batch: 301	Avg-Loss: 0.5232
# Epoch: 90	 Training Accuracy: 81.2700	 Validation Accuracy: 76.2500	 Avg-Loss: 0.5232
# Epoch    91: reducing learning rate of group 0 to 1.7715e-07.
# Epoch: 91	Batch: 1	Avg-Loss: 0.4646
# Epoch: 91	Batch: 101	Avg-Loss: 0.5282
# Epoch: 91	Batch: 201	Avg-Loss: 0.5290
# Epoch: 91	Batch: 301	Avg-Loss: 0.5275
# Epoch: 91	 Training Accuracy: 81.2760	 Validation Accuracy: 76.2500	 Avg-Loss: 0.5248
# Epoch: 92	Batch: 1	Avg-Loss: 0.5501
# Epoch: 92	Batch: 101	Avg-Loss: 0.5226
# Epoch: 92	Batch: 201	Avg-Loss: 0.5303
# Epoch: 92	Batch: 301	Avg-Loss: 0.5247
# Epoch: 92	 Training Accuracy: 81.2440	 Validation Accuracy: 76.2500	 Avg-Loss: 0.5261
# Epoch: 93	Batch: 1	Avg-Loss: 0.5432
# Epoch: 93	Batch: 101	Avg-Loss: 0.5329
# Epoch: 93	Batch: 201	Avg-Loss: 0.5226
# Epoch: 93	Batch: 301	Avg-Loss: 0.5203
# Epoch: 93	 Training Accuracy: 81.2720	 Validation Accuracy: 76.2500	 Avg-Loss: 0.5225
# Epoch: 94	Batch: 1	Avg-Loss: 0.5995
# Epoch: 94	Batch: 101	Avg-Loss: 0.5226
# Epoch: 94	Batch: 201	Avg-Loss: 0.5329
# Epoch: 94	Batch: 301	Avg-Loss: 0.5279
# Epoch: 94	 Training Accuracy: 81.3540	 Validation Accuracy: 76.2500	 Avg-Loss: 0.5260
# Epoch    95: reducing learning rate of group 0 to 5.3144e-08.
# Epoch: 95	Batch: 1	Avg-Loss: 0.5434
# Epoch: 95	Batch: 101	Avg-Loss: 0.5317
# Epoch: 95	Batch: 201	Avg-Loss: 0.5240
# Epoch: 95	Batch: 301	Avg-Loss: 0.5244
# Epoch: 95	 Training Accuracy: 81.2960	 Validation Accuracy: 76.2500	 Avg-Loss: 0.5226
# Epoch: 96	Batch: 1	Avg-Loss: 0.6309
# Epoch: 96	Batch: 101	Avg-Loss: 0.5349
# Epoch: 96	Batch: 201	Avg-Loss: 0.5229
# Epoch: 96	Batch: 301	Avg-Loss: 0.5199
# Epoch: 96	 Training Accuracy: 81.3340	 Validation Accuracy: 76.2500	 Avg-Loss: 0.5221
# Epoch: 97	Batch: 1	Avg-Loss: 0.5441
# Epoch: 97	Batch: 101	Avg-Loss: 0.5301
# Epoch: 97	Batch: 201	Avg-Loss: 0.5224
# Epoch: 97	Batch: 301	Avg-Loss: 0.5231
# Epoch: 97	 Training Accuracy: 81.3640	 Validation Accuracy: 76.2500	 Avg-Loss: 0.5209
# Epoch: 98	Batch: 1	Avg-Loss: 0.7177
# Epoch: 98	Batch: 101	Avg-Loss: 0.5184
# Epoch: 98	Batch: 201	Avg-Loss: 0.5246
# Epoch: 98	Batch: 301	Avg-Loss: 0.5230
# Epoch: 98	 Training Accuracy: 81.2460	 Validation Accuracy: 76.2500	 Avg-Loss: 0.5245
# Epoch    99: reducing learning rate of group 0 to 1.5943e-08.
# Epoch: 99	Batch: 1	Avg-Loss: 0.5970
# Epoch: 99	Batch: 101	Avg-Loss: 0.5261
# Epoch: 99	Batch: 201	Avg-Loss: 0.5238
# Epoch: 99	Batch: 301	Avg-Loss: 0.5224
# Epoch: 99	 Training Accuracy: 81.3380	 Validation Accuracy: 76.2500	 Avg-Loss: 0.5244
